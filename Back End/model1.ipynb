# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
col_names = ('State_Name','District_Name','Crop_Year','Season','Crop','Area','Production')

data=pd.read_csv("apy.csv")
data.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
data.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.423610e+05
# mean     2005.643018  1.200282e+04  5.825034e+05
# std         4.952164  5.052340e+04  1.706581e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  8.800000e+01
# 50%      2006.000000  5.820000e+02  7.290000e+02
# 75%      2010.000000  4.392000e+03  7.023000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
data.isnull().sum(axis = 0)
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns

# %%
missing_values_table(data)
# Out:
# Your selected dataframe has 7 columns.
# There are 1 columns that have missing values.
#             Missing Values  % of Total Values
# Production            3730                1.5

# %%
# dropping rows with null values in production
data = data.dropna()
data = data.reset_index(drop=True)
data.isnull().sum(axis = 0)
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
data['P_in_tonnes_per_hectar'] = data['Production']/data['Area']
data = data.drop(['Production'],axis=1)

# %%
data
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 242356                  West Bengal       PURULIA       2014  Summer
# 242357                  West Bengal       PURULIA       2014  Summer
# 242358                  West Bengal       PURULIA       2014  Whole Year
# 242359                  West Bengal       PURULIA       2014  Winter
# 242360                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  P_in_tonnes_per_hectar
# 0                  Arecanut    1254.0                1.594896
# 1       Other Kharif pulses       2.0                0.500000
# 2                      Rice     102.0                3.147059
# 3                    Banana     176.0                3.642045
# 4                 Cashewnut     720.0                0.229167
# ...                     ...       ...                     ...
# 242356                 Rice     306.0                2.617647
# 242357              Sesamum     627.0                0.738437
# 242358            Sugarcane     324.0               50.154321
# 242359                 Rice  279151.0                2.141848
# 242360              Sesamum     175.0                0.502857
#
# [242361 rows x 7 columns]

# %%
#encode the categorical values in these columns 'State_Name','District_Name','Crop_Year','Season','Crop' to numerical values
from sklearn.preprocessing import LabelEncoder
stateEncoder = LabelEncoder()
data['State_Name'] = stateEncoder.fit_transform(data['State_Name'])

districtEncoder = LabelEncoder()
data['District_Name'] = districtEncoder.fit_transform(data['District_Name'])

yearEncoder = LabelEncoder()
data['Crop_Year'] = yearEncoder.fit_transform(data['Crop_Year'])

seasonEncoder = LabelEncoder()
data['Season'] = seasonEncoder.fit_transform(data['Season'])

cropNameEncoder = LabelEncoder()
data['Crop'] = cropNameEncoder.fit_transform(data['Crop'])

# %%
data
# Out:
#         State_Name  District_Name  Crop_Year  Season  Crop      Area  \
# 0                0            427          3       1     2    1254.0
# 1                0            427          3       1    74       2.0
# 2                0            427          3       1    95     102.0
# 3                0            427          3       4     7     176.0
# 4                0            427          3       4    22     720.0
# ...            ...            ...        ...     ...   ...       ...
# 242356          32            471         17       3    95     306.0
# 242357          32            471         17       3   102     627.0
# 242358          32            471         17       4   106     324.0
# 242359          32            471         17       5    95  279151.0
# 242360          32            471         17       5   102     175.0
#
#         P_in_tonnes_per_hectar
# 0                     1.594896
# 1                     0.500000
# 2                     3.147059
# 3                     3.642045
# 4                     0.229167
# ...                        ...
# 242356                2.617647
# 242357                0.738437
# 242358               50.154321
# 242359                2.141848
# 242360                0.502857
#
# [242361 rows x 7 columns]

# %%
# Save these encoders so that they can be used in later phase
import numpy as np
#saving encoder
#encoder = LabelEncoder()
#encoder.fit(X)
#numpy.save('classes.npy', encoder.classes_)

#loading encoder
#encoder = LabelEncoder()
#encoder.classes_ = numpy.load('classes.npy')

np.save('stateEncoderClasses.npy',stateEncoder)
np.save('districtEncoderClasses.npy',stateEncoder)
np.save('yearEncoderClasses.npy',stateEncoder)
np.save('seasonEncoderClasses.npy',stateEncoder)
np.save('cropNameEncoderClasses.npy',stateEncoder)

# %%
# split into input (X) and output (Y) variables

# To convert into ndarray and then to X and Y
dataset = data.values
X = dataset[:,0:6]
Y = dataset[:,6]

# %%
print("X shape = ",X.shape)
print("Y shape = ",Y.shape)
# Out:
# X shape =  (242361, 6)
# Y shape =  (242361,)

# %%
# Import the keras modules
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Input, Dense
from keras.models import Model


def build_model():
  model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(6,)),
    #layers.Dense(64*64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 128)               896
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 9,217
# Trainable params: 9,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit( X,Y,epochs=10, validation_split = 0.2)
# Out:
# Train on 193888 samples, validate on 48473 samples
# Epoch 1/10
# 193888/193888 [==============================] - 6s 31us/sample - loss: 1053810.7209 - mean_absolute_error: 116.1554 - mean_squared_error: 1053810.6250 - val_loss: 290007.1507 - val_mean_absolute_error: 82.4952 - val_mean_squared_error: 290007.1250
# Epoch 2/10
# 193888/193888 [==============================] - 6s 31us/sample - loss: 800139.9333 - mean_absolute_error: 70.1363 - mean_squared_error: 800139.5000 - val_loss: 146920.8211 - val_mean_absolute_error: 26.3120 - val_mean_squared_error: 146920.9219
# Epoch 3/10
# 193888/193888 [==============================] - 6s 31us/sample - loss: 799565.7742 - mean_absolute_error: 72.3860 - mean_squared_error: 799564.3750 - val_loss: 148095.9434 - val_mean_absolute_error: 27.8519 - val_mean_squared_error: 148096.0312
# Epoch 4/10
# 193888/193888 [==============================] - 6s 30us/sample - loss: 799593.0733 - mean_absolute_error: 74.7379 - mean_squared_error: 799594.1875 - val_loss: 182039.1936 - val_mean_absolute_error: 66.9176 - val_mean_squared_error: 182039.1562
# Epoch 5/10
# 193888/193888 [==============================] - 6s 30us/sample - loss: 798813.9560 - mean_absolute_error: 77.3199 - mean_squared_error: 798814.3125 - val_loss: 146969.7699 - val_mean_absolute_error: 26.6666 - val_mean_squared_error: 146969.7969
# Epoch 6/10
# 193888/193888 [==============================] - 6s 30us/sample - loss: 798309.8174 - mean_absolute_error: 72.9886 - mean_squared_error: 798309.7500 - val_loss: 148276.2379 - val_mean_absolute_error: 24.8977 - val_mean_squared_error: 148276.3438
# Epoch 7/10
# 193888/193888 [==============================] - 6s 30us/sample - loss: 797392.4417 - mean_absolute_error: 69.7959 - mean_squared_error: 797392.1875 - val_loss: 146924.1715 - val_mean_absolute_error: 21.6717 - val_mean_squared_error: 146924.1250
# Epoch 8/10
# 193888/193888 [==============================] - 6s 33us/sample - loss: 807375.8746 - mean_absolute_error: 69.3894 - mean_squared_error: 807376.0625 - val_loss: 146711.1942 - val_mean_absolute_error: 25.9576 - val_mean_squared_error: 146711.0312
# Epoch 9/10
# 193888/193888 [==============================] - 6s 31us/sample - loss: 797573.8705 - mean_absolute_error: 69.0664 - mean_squared_error: 797573.1875 - val_loss: 148378.3932 - val_mean_absolute_error: 50.5608 - val_mean_squared_error: 148378.3281
# Epoch 10/10
# 193888/193888 [==============================] - 6s 30us/sample - loss: 803466.5851 - mean_absolute_error: 72.4462 - mean_squared_error: 803466.0625 - val_loss: 147036.2063 - val_mean_absolute_error: 32.2249 - val_mean_squared_error: 147036.2812
